# %%
from collections import defaultdict
dic = defaultdict(list)
dic['a'].append([1, 2, 3])
dic['b'].append([4, 5, 6])
print(dic)
# Out:
# defaultdict(<class 'list'>, {'a': [[1, 2, 3]], 'b': [[4, 5, 6]]})

# %%
setb = defaultdict(set)
setb['a'].add((1, 1, 1))
print(setb)
# Out:
# defaultdict(<class 'set'>, {'a': {(1, 1, 1)}})

# %%
nums = [1,1,1,2,2,3]

# %%
slow = 2
fast = 2

while fast < len(nums) - 1 :
    if nums[fast] != nums[slow]:
        nums[slow] = nums[fast]
        slow += 1
    fast +=1

# %%
slow
# Out:
# [1, 1, 2, 2, 2, 3]

# %%
n = float('inf')

# %%
nums = [1,1,1,2,2,3]
ch ="abbbcccdd"

# %%
count = {}
for i in nums:
    count[i] = count.get(i,0) +1

# %%
count
# Out:
# {1: 3, 2: 2, 3: 1}

# %%
nums = [1,1,1,2,2,3]

# %%
sum = sum(i for i in nums)

# %%
sum
# Out:
# 10

# %%
nums1 = list(map(lambda x:x**2, nums))

# %%
nums1
# Out:
# [1, 1, 1, 4, 4, 9]

# %%
s = "abbccddeeg"
char = {}

# %%
for i in s:
    char[i] = char.get(i,0) + 1
    if char[i] > 1:
        del char[i]
    
print(char)
# Out:
# {'a': 1, 'g': 1}

# %%
len(char)
# Out:
# 2

# %%
l = s.strip()

# %%
print(l)
# Out:
# abbccddeeg

# %%
l = s.split()

# %%
l
# Out:
# ['abbccddeeg']

# %%
l1 = list(s)

# %%
print(l1)
# Out:
# ['a', 'b', 'b', 'c', 'c', 'd', 'd', 'e', 'e', 'g']
